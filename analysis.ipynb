# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %% [markdown]
# #### Importing the dataset

# %%
market_data = pd.read_csv("Data/NSE_Listings.csv")

# %%
market_data.shape
# Out:
# (1930, 8)

# %%
market_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1930 entries, 0 to 1929
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SYMBOL            1930 non-null   object
#  1   NAME OF COMPANY   1930 non-null   object
#  2    SERIES           1930 non-null   object
#  3    DATE OF LISTING  1930 non-null   object
#  4    PAID UP VALUE    1930 non-null   int64
#  5    MARKET LOT       1930 non-null   int64
#  6    ISIN NUMBER      1930 non-null   object
#  7    FACE VALUE       1930 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 120.8+ KB

# %%
market_data
# Out:
#           SYMBOL                           NAME OF COMPANY  SERIES  \
# 0      20MICRONS                        20 Microns Limited      BE
# 1     21STCENMGM  21st Century Management Services Limited      EQ
# 2         360ONE                       360 ONE WAM LIMITED      EQ
# 3      3IINFOLTD                       3i Infotech Limited      EQ
# 4        3MINDIA                          3M India Limited      EQ
# ...          ...                                       ...     ...
# 1925        ZOTA                  Zota Health Care LImited      EQ
# 1926       ZUARI              Zuari Agro Chemicals Limited      EQ
# 1927    ZUARIIND                  ZUARI INDUSTRIES LIMITED      EQ
# 1928   ZYDUSLIFE                Zydus Lifesciences Limited      EQ
# 1929   ZYDUSWELL                    Zydus Wellness Limited      EQ
#
#       DATE OF LISTING   PAID UP VALUE   MARKET LOT   ISIN NUMBER   FACE VALUE
# 0         06-OCT-2008               5            1  INE144J01027            5
# ...

# %%
market_cap_data = pd.read_csv("Data/NSE_Listings_MarketCap.csv")

# %%
market_cap_data.shape
# Out:
# (2139, 3)

# %%
market_cap_data
# Out:
#           Symbol                               Company Name  \
# 0       RELIANCE                Reliance Industries Limited
# 1            TCS          Tata Consultancy Services Limited
# 2       HDFCBANK                          HDFC Bank Limited
# 3      ICICIBANK                         ICICI Bank Limited
# 4     HINDUNILVR                 Hindustan Unilever Limited
# ...          ...                                        ...
# 2134  VIVIMEDLAB                       Vivimed Labs Limited
# 2135     WINSOME                      Winsome Yarns Limited
# 2136       ZICOM  Zicom Electronic Security Systems Limited
# 2137         NaN                                        NaN
# 2138         NaN                                        NaN
#
#      Market capitalization as on March 31, 2023\n(Rs in Lakhs)
# 0                                      157706937.768198
# 1                                      117305527.967007
# 2                                     89808750.01206301
# ...

# %%
market_cap_data.rename(columns={'Market capitalization as on March 31, 2023\n(Rs in Lakhs)':'MarketCap_upto_31/03/2023_(in Crores)'},inplace=True)

# %%
market_cap_data
# Out:
#           Symbol                               Company Name  \
# 0       RELIANCE                Reliance Industries Limited
# 1            TCS          Tata Consultancy Services Limited
# 2       HDFCBANK                          HDFC Bank Limited
# 3      ICICIBANK                         ICICI Bank Limited
# 4     HINDUNILVR                 Hindustan Unilever Limited
# ...          ...                                        ...
# 2134  VIVIMEDLAB                       Vivimed Labs Limited
# 2135     WINSOME                      Winsome Yarns Limited
# 2136       ZICOM  Zicom Electronic Security Systems Limited
# 2137         NaN                                        NaN
# 2138         NaN                                        NaN
#
#                 MarketCap_upto_31/03/2023_(in Crores)
# 0                                    157706937.768198
# 1                                    117305527.967007
# 2                                   89808750.01206301
# ...

# %%
market_cap_data['MarketCap_upto_31/03/2023_(in Crores)'].value_counts()
# Out:
# MarketCap_upto_31/03/2023_(in Crores)
# *Not available for trading as on March 31, 2023    124
# 26725.189661999997                                   1
# 26035.685                                            1
# 26105.5104                                           1
# 26149.371255                                         1
#                                                   ...
# 236484.18043799998                                   1
# 236634.58873                                         1
# 236799.6725                                          1
# 239363.28702                                         1
# 80756.93568149999                                    1
# Name: count, Length: 2014, dtype: int64

# %%
market_cap_data[market_cap_data['MarketCap_upto_31/03/2023_(in Crores)']=='*Not available for trading as on March 31, 2023']
# Out:
#           Symbol                               Company Name  \
# 2013    ABHISHEK               Abhishek Corporation Limited
# 2014     AHLWEST                Asian Hotels (West) Limited
# 2015        AIFL         Ashapura Intimates Fashion Limited
# 2016    AJRINFRA              AJR Infra And Tolling Limited
# 2017      ALCHEM                          Alchemist Limited
# ...          ...                                        ...
# 2132   VIKASPROP           Vikas Proppant & Granite Limited
# 2133    VISUINTL                 Visu International Limited
# 2134  VIVIMEDLAB                       Vivimed Labs Limited
# 2135     WINSOME                      Winsome Yarns Limited
# 2136       ZICOM  Zicom Electronic Security Systems Limited
#
#                 MarketCap_upto_31/03/2023_(in Crores)
# 2013  *Not available for trading as on March 31, 2023
# 2014  *Not available for trading as on March 31, 2023
# 2015  *Not available for trading as on March 31, 2023
# ...

# %%
nan_rows = market_cap_data.isna().any(axis=1)
market_cap_data[nan_rows]
# Out:
#      Symbol Company Name MarketCap_upto_31/03/2023_(in Crores)
# 2137    NaN          NaN                                   NaN
# 2138    NaN          NaN                                   NaN

# %%
market_cap_data.dropna(axis=0, inplace=True)

# %%
indices_to_be_dropped = market_cap_data[market_cap_data['MarketCap_upto_31/03/2023_(in Crores)']=='*Not available for trading as on March 31, 2023'].index
market_cap_data.drop(indices_to_be_dropped, inplace=True)

# %% [markdown]
# Conditional dropping of indices/rows; Much cleaner than simply hardcoding the index values of the rows to be dropped

# %%
#((market_cap_data['MarketCap_upto_31/03/2023'].astype(float)/100).round()).astype(int)

# %%
market_cap_data['MarketCap_upto_31/03/2023_(in Crores)'] = ((market_cap_data['MarketCap_upto_31/03/2023_(in Crores)'].astype(float)/100).round()).astype(int)

# %% [markdown]
# We convert the series dtype to 'float' so that we can divide it by 100(conversion to Crores) and then round it up using the rounf method. Then finally we convert the entire dtype of the series to 'int' so that we get rid of the .0 decimal.

# %%
market_cap_data.head()
# Out:
#        Symbol                       Company Name  \
# 0    RELIANCE        Reliance Industries Limited
# 1         TCS  Tata Consultancy Services Limited
# 2    HDFCBANK                  HDFC Bank Limited
# 3   ICICIBANK                 ICICI Bank Limited
# 4  HINDUNILVR         Hindustan Unilever Limited
#
#    MarketCap_upto_31/03/2023_(in Crores)
# 0                                1577069
# 1                                1173055
# 2                                 898088
# 3                                 612483
# 4                                 601578
